# %%
import numpy as np
import visbrain as vb
from visbrain.objects import BrainObj, SceneObj, SourceObj

# %%
ROI_list = open('/media/corey/4TB-WDBlue/data-thesis/ROI_list.txt')
ROIs = ROI_list.readlines()

# %%
#Concatenate all coordinates of Max Fs from each group (control vs non-affective)
#Done in shell

# %%
#Read in list of Max F coordinates from subject directories
All_points_to_plot1 = []
All_points_to_plot2 = []
labels = []
scenes = []
for roi in ROIs:
    roi = roi.strip()
    labels.append(roi)
    points_to_plot = []
    points_to_plot2 = []
    F1_list_c = open('/media/corey/4TB-WDBlue/data-thesis/fMRI/Rapidtide_concatenated_positions/F1_c/%s_mmconcat.txt' %roi)
    F2_list_c = open('/media/corey/4TB-WDBlue/data-thesis/fMRI/Rapidtide_concatenated_positions/F2_c/%s_mmconcat.txt' %roi)
    F1_c_coords = F1_list_c.readlines()
    F2_c_coords = F2_list_c.readlines()
    #Frequency Band 1
    stripped_dmPFC = [s.strip() for s in F1_c_coords]
    split_stripped = [s.split() for s in stripped_dmPFC]
    #Frequency Band 2
    stripped_dmPFC2 = [s.strip() for s in F2_c_coords]
    split_stripped2 = [s.split() for s in stripped_dmPFC2]


    for n in range(0,len(F1_c_coords)-1):
        f_dmPFC = [float(s) for s in split_stripped[n]]
        points_to_plot.append(np.array(f_dmPFC))
        f_dmPFC_2 = [float(s) for s in split_stripped2[n]]
        points_to_plot2.append(np.array(f_dmPFC_2))

    All_points_to_plot1.append(np.array(points_to_plot))
    All_points_to_plot2.append(np.array(points_to_plot2))

print(labels)

for r, roi in enumerate(ROIs):
#Defining source and brain objects
    b_obj = BrainObj('B1')

    s_obj = SourceObj('%s' %roi, All_points_to_plot1[r])
    s_obj_2 = SourceObj('%s' %roi, All_points_to_plot2[r],color='blue')
#Black background scene
    sc = SceneObj(bgcolor='black')

    sc.add_to_subplot(b_obj,row=0,col=0)
    sc.add_to_subplot(s_obj,row=0,col=0)
    sc.add_to_subplot(s_obj_2,row=0,col=0)
    sc.preview()
    #sc.screenshot('/media/corey/4TB-WDBlue/data-thesis/fMRI/imagesMaxF_c/%s_MaxF.png' %roi,autocrop=True)
# Out:
# BrainObj(name='B1') created
# SourceObj(name='dACC
# ') created
#     38 sources detected
# SourceObj(name='dACC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='dACC
# ') added to the scene
#     SourceObj(name='dACC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# ['dACC', 'dmPFC', 'LaPFC', 'LaPFC_SN', 'LIns', 'LiTem', 'LlPar', 'LlPar_SN', 'LpCerb', 'LsPar', 'mdThal', 'mPFC', 'PCCandPrecuneus', 'RaPFC', 'R_aPFC_SN', 'RIns', 'RiTem', 'RlPar', 'RlPar_SN', 'RpCerb', 'RsPar']
# BrainObj(name='B1') created
# SourceObj(name='dmPFC
# ') created
#     38 sources detected
# SourceObj(name='dmPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='dmPFC
# ') added to the scene
#     SourceObj(name='dmPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LaPFC
# ') created
#     38 sources detected
# SourceObj(name='LaPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LaPFC
# ') added to the scene
#     SourceObj(name='LaPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LaPFC_SN
# ') created
#     38 sources detected
# SourceObj(name='LaPFC_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LaPFC_SN
# ') added to the scene
#     SourceObj(name='LaPFC_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LIns
# ') created
#     38 sources detected
# SourceObj(name='LIns
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LIns
# ') added to the scene
#     SourceObj(name='LIns
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LiTem
# ') created
#     38 sources detected
# SourceObj(name='LiTem
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LiTem
# ') added to the scene
#     SourceObj(name='LiTem
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LlPar
# ') created
#     38 sources detected
# SourceObj(name='LlPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LlPar
# ') added to the scene
#     SourceObj(name='LlPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LlPar_SN
# ') created
#     38 sources detected
# SourceObj(name='LlPar_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LlPar_SN
# ') added to the scene
#     SourceObj(name='LlPar_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LpCerb
# ') created
#     38 sources detected
# SourceObj(name='LpCerb
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LpCerb
# ') added to the scene
#     SourceObj(name='LpCerb
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LsPar
# ') created
#     38 sources detected
# SourceObj(name='LsPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LsPar
# ') added to the scene
#     SourceObj(name='LsPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='mdThal
# ') created
#     38 sources detected
# SourceObj(name='mdThal
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='mdThal
# ') added to the scene
#     SourceObj(name='mdThal
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='mPFC
# ') created
#     38 sources detected
# SourceObj(name='mPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='mPFC
# ') added to the scene
#     SourceObj(name='mPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='PCCandPrecuneus
# ') created
#     38 sources detected
# SourceObj(name='PCCandPrecuneus
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='PCCandPrecuneus
# ') added to the scene
#     SourceObj(name='PCCandPrecuneus
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RaPFC
# ') created
#     38 sources detected
# SourceObj(name='RaPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RaPFC
# ') added to the scene
#     SourceObj(name='RaPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='R_aPFC_SN
# ') created
#     38 sources detected
# SourceObj(name='R_aPFC_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='R_aPFC_SN
# ') added to the scene
#     SourceObj(name='R_aPFC_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RIns
# ') created
#     38 sources detected
# SourceObj(name='RIns
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RIns
# ') added to the scene
#     SourceObj(name='RIns
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RiTem
# ') created
#     38 sources detected
# SourceObj(name='RiTem
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RiTem
# ') added to the scene
#     SourceObj(name='RiTem
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RlPar
# ') created
#     38 sources detected
# SourceObj(name='RlPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RlPar
# ') added to the scene
#     SourceObj(name='RlPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RlPar_SN
# ') created
#     38 sources detected
# SourceObj(name='RlPar_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RlPar_SN
# ') added to the scene
#     SourceObj(name='RlPar_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RpCerb
# ') created
#     38 sources detected
# SourceObj(name='RpCerb
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RpCerb
# ') added to the scene
#     SourceObj(name='RpCerb
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RsPar
# ') created
#     38 sources detected
# SourceObj(name='RsPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RsPar
# ') added to the scene
#     SourceObj(name='RsPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`

# %%
#Read in list of Max F coordinates from subject directories
All_points_to_plot1 = []
All_points_to_plot2 = []
labels = []
scenes = []
for roi in ROIs:
    roi = roi.strip()
    labels.append(roi)
    points_to_plot = []
    points_to_plot2 = []
    F1_list_n = open('/media/corey/4TB-WDBlue/data-thesis/fMRI/Rapidtide_concatenated_positions/F1_n/%s_mmconcat.txt' %roi)
    F2_list_n = open('/media/corey/4TB-WDBlue/data-thesis/fMRI/Rapidtide_concatenated_positions/F2_n/%s_mmconcat.txt' %roi)
    F1_n_coords = F1_list_n.readlines()
    F2_n_coords = F2_list_n.readlines()
    #Frequency Band 1
    stripped_dmPFC = [s.strip() for s in F1_n_coords]
    split_stripped = [s.split() for s in stripped_dmPFC]
    #Frequency Band 2
    stripped_dmPFC2 = [s.strip() for s in F2_n_coords]
    split_stripped2 = [s.split() for s in stripped_dmPFC2]


    for n in range(0,len(F1_c_coords)-1):
        f_dmPFC = [float(s) for s in split_stripped[n]]
        points_to_plot.append(np.array(f_dmPFC))
        f_dmPFC_2 = [float(s) for s in split_stripped2[n]]
        points_to_plot2.append(np.array(f_dmPFC_2))

    All_points_to_plot1.append(np.array(points_to_plot))
    All_points_to_plot2.append(np.array(points_to_plot2))

print(labels)

for r, roi in enumerate(ROIs):
#Defining source and brain objects
    b_obj = BrainObj('B1')

    s_obj = SourceObj('%s' %roi, All_points_to_plot1[r])
    s_obj_2 = SourceObj('%s' %roi, All_points_to_plot2[r],color='blue')
#Black background scene
    sc = SceneObj(bgcolor='black')

    sc.add_to_subplot(b_obj,row=0,col=0)
    sc.add_to_subplot(s_obj,row=0,col=0)
    sc.add_to_subplot(s_obj_2,row=0,col=0)
    sc.preview()
    sc.screenshot('/media/corey/4TB-WDBlue/data-thesis/fMRI/imagesMaxF_n/%s_MaxF.png' %roi,autocrop=True)
# Out:
# BrainObj(name='B1') created
# SourceObj(name='dACC
# ') created
#     38 sources detected
# SourceObj(name='dACC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='dACC
# ') added to the scene
#     SourceObj(name='dACC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# ['dACC', 'dmPFC', 'LaPFC', 'LaPFC_SN', 'LIns', 'LiTem', 'LlPar', 'LlPar_SN', 'LpCerb', 'LsPar', 'mdThal', 'mPFC', 'PCCandPrecuneus', 'RaPFC', 'R_aPFC_SN', 'RIns', 'RiTem', 'RlPar', 'RlPar_SN', 'RpCerb', 'RsPar']
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='dmPFC
# ') created
#     38 sources detected
# SourceObj(name='dmPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='dmPFC
# ') added to the scene
#     SourceObj(name='dmPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LaPFC
# ') created
#     38 sources detected
# SourceObj(name='LaPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LaPFC
# ') added to the scene
#     SourceObj(name='LaPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LaPFC_SN
# ') created
#     38 sources detected
# SourceObj(name='LaPFC_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LaPFC_SN
# ') added to the scene
#     SourceObj(name='LaPFC_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LIns
# ') created
#     38 sources detected
# SourceObj(name='LIns
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LIns
# ') added to the scene
#     SourceObj(name='LIns
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LiTem
# ') created
#     38 sources detected
# SourceObj(name='LiTem
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LiTem
# ') added to the scene
#     SourceObj(name='LiTem
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LlPar
# ') created
#     38 sources detected
# SourceObj(name='LlPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LlPar
# ') added to the scene
#     SourceObj(name='LlPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LlPar_SN
# ') created
#     38 sources detected
# SourceObj(name='LlPar_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LlPar_SN
# ') added to the scene
#     SourceObj(name='LlPar_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LpCerb
# ') created
#     38 sources detected
# SourceObj(name='LpCerb
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LpCerb
# ') added to the scene
#     SourceObj(name='LpCerb
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='LsPar
# ') created
#     38 sources detected
# SourceObj(name='LsPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='LsPar
# ') added to the scene
#     SourceObj(name='LsPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='mdThal
# ') created
#     38 sources detected
# SourceObj(name='mdThal
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='mdThal
# ') added to the scene
#     SourceObj(name='mdThal
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='mPFC
# ') created
#     38 sources detected
# SourceObj(name='mPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='mPFC
# ') added to the scene
#     SourceObj(name='mPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='PCCandPrecuneus
# ') created
#     38 sources detected
# SourceObj(name='PCCandPrecuneus
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='PCCandPrecuneus
# ') added to the scene
#     SourceObj(name='PCCandPrecuneus
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RaPFC
# ') created
#     38 sources detected
# SourceObj(name='RaPFC
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RaPFC
# ') added to the scene
#     SourceObj(name='RaPFC
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='R_aPFC_SN
# ') created
#     38 sources detected
# SourceObj(name='R_aPFC_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='R_aPFC_SN
# ') added to the scene
#     SourceObj(name='R_aPFC_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RIns
# ') created
#     38 sources detected
# SourceObj(name='RIns
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RIns
# ') added to the scene
#     SourceObj(name='RIns
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RiTem
# ') created
#     38 sources detected
# SourceObj(name='RiTem
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RiTem
# ') added to the scene
#     SourceObj(name='RiTem
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RlPar
# ') created
#     38 sources detected
# SourceObj(name='RlPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RlPar
# ') added to the scene
#     SourceObj(name='RlPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RlPar_SN
# ') created
#     38 sources detected
# SourceObj(name='RlPar_SN
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RlPar_SN
# ') added to the scene
#     SourceObj(name='RlPar_SN
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RpCerb
# ') created
#     38 sources detected
# SourceObj(name='RpCerb
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RpCerb
# ') added to the scene
#     SourceObj(name='RpCerb
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# BrainObj(name='B1') created
# SourceObj(name='RsPar
# ') created
#     38 sources detected
# SourceObj(name='RsPar
# ') created
#     38 sources detected
# Creation of a scene
#     BrainObj(name='B1') added to the scene
#     SourceObj(name='RsPar
# ') added to the scene
#     SourceObj(name='RsPar
# ') added to the scene
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
# WARNING | dpi parameter is not active if `print_size` is None. Use for example `print_size=(5, 5)`
